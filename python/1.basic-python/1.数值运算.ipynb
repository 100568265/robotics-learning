# %%
# 取余
10%3
# Out:
# 1

# %%
# 乘方
2**3
# Out:
# 8

# %%
# 绝对值
abs(-15.6)
# Out:
# 15.6

# %%
# 取最大值
max(2,3,4,5)
# Out:
# 5

# %%
# 取最小值
min(2,3,4,5)
# Out:
# 2

# %%
# 四舍五入
round(15.6)
# Out:
# 16
