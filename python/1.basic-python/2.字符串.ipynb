# %%
str1 = 'hello' + 'python'
str1
# Out:
# 'hellopython'

# %%
str2 = '1 2 3 4 5'
str2.split() # 默认以空格切分
# Out:
# ['1', '2', '3', '4', '5']

# %%
str3 = '1,2,3,4,5'
str3.split(",") # 以逗号切分
# Out:
# ['1', '2', '3', '4', '5']

# %%
# 替换操作
str4 = 'hello python'
str5 = str4.replace('python', 'world')
str5
# Out:
# 'hello world'

# %%
# 换成大写
str5.upper()
# Out:
# 'HELLO WORLD'

# %%
# 去空格
str6 = '     hello python     '
str6.strip()
# Out:
# 'hello python'
